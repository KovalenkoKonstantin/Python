# %% [markdown]
# Для выбора случайного элемента списка можно использовать функцию choice()
#
# from random import choice
# l = ["Мику", "Сакура", "Тоши", "Инти"]
# print(choice(l), "пойдет в магазин за продуктами")
# может выводить
#
# Тоши пойдет в магазин за продуктами

# %% [markdown]
# Сакура не любит запоминать много названий функций, по этому пишет свои. Помогите Сакуре и исправь ошибки в ее коде так, чтобы функция vibrat_sluchainii_element, возвращала случайный элемент списка l

# %%
from random import choice

def vibrat_sluchainii_element(l):
    return choice(l)

l = [1, 2, 3, 4, 5, 39, 12345]
for i in range(1000):
    print(vibrat_sluchainii_element(l))
# Out:
# 1
# 5
# 4
# 5
# 3
# 2
# 2
# 2
# 3
# 3
# 3
# 4
# 12345
# 39
# 5
# 3
# 12345
# 1
# 5
# 4
# 5
# 39
# 5
# 12345
# 3
# 4
# 5
# 1
# 4
# 12345
# 3
# 1
# 2
# 2
# 2
# 12345
# 12345
# 12345
# 3
# 4
# 1
# 3
# 2
# 3
# 5
# 39
# 3
# 3
# 4
# 3
# 39
# 4
# 1
# 12345
# 5
# 2
# 39
# 1
# 1
# 12345
# 4
# 1
# 3
# 1
# 4
# 2
# 4
# 3
# 39
# 39
# 5
# 5
# 5
# 5
# 1
# 3
# 4
# 2
# 5
# 39
# 5
# 2
# 1
# 1
# 39
# 5
# 4
# 1
# 1
# 1
# 12345
# 1
# 5
# 4
# 3
# 4
# 39
# 1
# 3
# 3
# 2
# 39
# 12345
# 39
# 39
# 12345
# 2
# 2
# 2
# 3
# 3
# 12345
# 4
# 1
# 12345
# 5
# 39
# 1
# 3
# 12345
# 5
# 12345
# 2
# 3
# 5
# 1
# 39
# 2
# 3
# 3
# 5
# 1
# 1
# 1
# 12345
# 2
# 4
# 5
# 2
# 5
# 4
# 4
# 2
# 2
# 4
# 12345
# 5
# 39
# 3
# 39
# 3
# 5
# 5
# 4
# 39
# 4
# 4
# 2
# 5
# 5
# 2
# 4
# 4
# 39
# 5
# 39
# 5
# 1
# 5
# 5
# 39
# 3
# 1
# 3
# 4
# 4
# 5
# 2
# 39
# 1
# 5
# 4
# 3
# 3
# 39
# 4
# 3
# 4
# 12345
# 2
# 12345
# 5
# 39
# 4
# 1
# 12345
# 3
# 39
# 12345
# 3
# 2
# 39
# 4
# 4
# 5
# 2
# 4
# 2
# 4
# 39
# 2
# 2
# 3
# 5
# 39
# 3
# 3
# 5
# 4
# 39
# ...

# %% [markdown]
# Напиши программу, которая сгенерирует случайную игральную карту (2, 3, 4, 5, 6, 7, 8, 9, 10, валет, дама, король, туз)
#
# одной из 4 мастей (червей, бубно, треф, пик)

# %%
from random import choice

card = [2, 3, 4, 5, 6, 7, 8, 9, 10, 'валет', 'дама', 'король', 'туз']
color = ['червей', 'бубно', 'треф', 'пик']

print(choice(card), choice(color))
